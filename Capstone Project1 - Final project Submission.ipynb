# %% [markdown]
# # Start Analysing the Capstone Project DataSet.

# %% [markdown]
# ### Import relevant  modules for analysing the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Lets extract out all datafiles from CSV to pandas dateframe so that we can analyze the data.

# %%
orders_df = pd.read_csv('C:\\Users\\rchauhan\\Desktop\\Springboard Materials\\Capstone Project Data\\orders.csv')
orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
department_df = pd.read_csv('C:\\Users\\rchauhan\\Desktop\\Springboard Materials\\Capstone Project Data\\departments.csv')
department_df.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
product_df = pd.read_csv('C:\\Users\\rchauhan\\Desktop\\Springboard Materials\\Capstone Project Data\\products.csv')
product_df.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
order_product_prior_df = pd.read_csv(r'C:\Users\rchauhan\Desktop\Springboard Materials\Capstone Project Data\order_products__prior.csv')
order_product_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_product_train_df = pd.read_csv(r'C:\Users\rchauhan\Desktop\Springboard Materials\Capstone Project Data\order_products__train.csv')

# %%
aisles_df = pd.read_csv(r'C:\Users\rchauhan\Desktop\Springboard Materials\Capstone Project Data\aisles.csv')
aisles_df.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %% [markdown]
# ### Lets do Prelimanary analysis of Orders Data.

# %%
#count user_ids for different evaluation set
count_eval_set_user = orders_df.groupby('eval_set').user_id.nunique().reset_index()
count_eval_set_user.columns = ['Eval_Set', 'Count_User_ID']
count_eval_set_user
# Out:
#   Eval_Set  Count_User_ID
# 0    prior         206209
# 1     test          75000
# 2    train         131209

# %%
#count order_ids for different evaluation set
count_eval_set_order = orders_df.groupby('eval_set').order_id.nunique().reset_index()
count_eval_set_order.columns = ['Eval_Set', 'Count_Orders']
count_eval_set_order
# Out:
#   Eval_Set  Count_Orders
# 0    prior       3214874
# 1     test         75000
# 2    train        131209

# %% [markdown]
# *** From above result we found out that there are close to 420 Thousands Users and 3.5 Millions Orders information for those users ***

# %% [markdown]
# ### Lets cleanup the data first before analyzing.

# %%
#remove unwanted any extra blank spaces in the department field
department_df['department'] = department_df['department'].str.strip()

# %%
#remove any Null values in the department label
department_df.dropna(axis=0,how='any',subset=['department']).head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
#remove unwanted any extra blank spaces in the product field
product_df['product_name'] = product_df['product_name'].str.strip()

# %%
#remove any Null values in the product label
product_df.dropna(axis=0,how='any',subset=['product_name']).head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %% [markdown]
# #### Checking if any more cleanup is required.

# %%
product_df[product_df['product_name'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
department_df[department_df['department'].isnull()]
# Out:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %% [markdown]
# ### Now we have done our prelimanary observation and data cleaning lets analyze the data and answer few intresting questions. ###
#
# *** 1. What is the odering trend of the users based on different day of week? ***
#
# *** 2. What is the odering trend of the users based on different hour of the day? ***
#
# *** 3. Find out summary of orders in different departments ? ***
#
# *** 4. How many products are re-ordered from different department? ***
#
# *** 5. What is the trend of re-odering the products in different day of the week? ***
#
# *** 6. What is the trend of re-odering the products in different in Morning, Afternnon, Eveining and Night? ***
#
# *** 7. Find which day of the week alcohol was bought the most. ***
#
# *** 8. Which day of the week and what hour of the day we see more number of orders than others. ***
#
# *** 9. Find out Frequency distribution of days since prior order was made. ***

# %%
def range_of_hr(var1):
    if (var1 >= 4) & (var1 < 12):
        a = 'Morning'
    elif (var1 >= 12) & (var1 < 17):
        a = 'Afternoon'
    elif (var1 >= 17) & (var1 < 22):
        a = 'Evening'
    else:
        a = 'Night'
    return a

# %%
def dow(val):
    if (val == 0):
        d = 'Sunday'
    elif (val == 1):
        d = 'Monday'
    elif (val == 2):
        d = 'Tuesday'    
    elif (val == 3):
        d = 'Wednesday'
    elif (val == 4):
        d = 'Thursday' 
    elif (val == 5):
        d = 'Friday'
    elif (val == 6):
        d = 'Saturday'  
    return d

# %%
orders_df['range_of_hr'] = orders_df.order_hour_of_day.apply(range_of_hr)
orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order range_of_hr
# 0                     NaN     Morning
# 1                    15.0     Morning
# 2                    21.0   Afternoon
# 3                    29.0     Morning
# 4                    28.0   Afternoon

# %%
orders_df['weekday'] = orders_df.order_dow.apply(dow)
orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order range_of_hr    weekday
# 0                     NaN     Morning    Tuesday
# 1                    15.0     Morning  Wednesday
# 2                    21.0   Afternoon  Wednesday
# 3                    29.0     Morning   Thursday
# 4                    28.0   Afternoon   Thursday

# %%
plt.figure(figsize = (16,8))
sns.countplot(x='weekday',data=orders_df)
plt.xlabel('Weekday',fontsize = 12)
plt.ylabel('Number of Orders',fontsize = 12)
plt.title('Distribution of Orders over the week',fontsize = 14)
plt.show()

# %% [markdown]
# *** We see that Monday and Sunday are most number of oders are done ***

# %%
plt.figure(figsize = (12,8))
sns.countplot(x='range_of_hr',data=orders_df)
plt.xlabel('range_of_hr',fontsize = 12)
plt.ylabel('Number of Orders',fontsize = 12)
plt.title('Distribution of Orders over a day',fontsize = 14)
plt.show()

# %% [markdown]
# *** We see that Afternoon is the time when most number of oders were made. ***

# %%
order_product_join_train = pd.merge(orders_df,order_product_train_df,how='inner',on='order_id')
order_product_join_train.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order range_of_hr   weekday  product_id  \
# 0                    14.0     Morning  Thursday         196
# 1                    14.0     Morning  Thursday       25133
# 2                    14.0     Morning  Thursday       38928
# 3                    14.0     Morning  Thursday       26405
# 4                    14.0     Morning  Thursday       39657
#
#    add_to_cart_order  reordered
# 0                  1          1
# 1                  2          1
# 2                  3          1
# 3                  4          1
# 4                  5          1

# %%
order_product = pd.merge(order_product_join_train,product_df,how='inner',on='product_id')
order_product_department = pd.merge(order_product,department_df,how='inner',on='department_id')
order_product_department_aisle = pd.merge(order_product_department,aisles_df,how='inner',on='aisle_id')
order_product_department_aisle.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   2757217       67    train            25          0                 11
# 2    632715      676    train            12          0                 13
# 3   1167274      760    train             5          4                 10
# 4   3347074      804    train            16          3                 21
#
#    days_since_prior_order range_of_hr    weekday  product_id  \
# 0                    14.0     Morning   Thursday         196
# 1                     5.0     Morning     Sunday         196
# 2                    26.0   Afternoon     Sunday         196
# 3                     8.0     Morning   Thursday         196
# 4                     5.0     Evening  Wednesday         196
#
#    add_to_cart_order  reordered product_name  aisle_id  department_id  \
# 0                  1          1         Soda        77              7
# 1                  1          1         Soda        77              7
# 2                  2          1         Soda        77              7
# 3                  2          1         Soda        77              7
# 4                  4          0         Soda        77              7
#
#   department        aisle
# 0  beverages  soft drinks
# 1  beverages  soft drinks
# 2  beverages  soft drinks
# 3  beverages  soft drinks
# 4  beverages  soft drinks

# %%
analysis_df = order_product_department_aisle[['user_id','order_id','product_name','department','aisle','order_dow','order_hour_of_day','days_since_prior_order','add_to_cart_order','reordered','range_of_hr','weekday']]

# %%
df = analysis_df.groupby('department').count()['order_id'].reset_index()
df.columns = ['Department','Total_Orders']
df.sort_values(by='Total_Orders',ascending=False)
# Out:
#          Department  Total_Orders
# 19          produce        409087
# 7        dairy eggs        217051
# 20           snacks        118862
# 3         beverages        114046
# 10           frozen        100426
# 16           pantry         81242
# 2            bakery         48394
# 6      canned goods         46799
# 8              deli         44291
# 9   dry goods pasta         38713
# 11        household         35986
# 13     meat seafood         30307
# 4         breakfast         29500
# 17    personal care         21570
# 1            babies         14941
# 12    international         11902
# 14          missing          8251
# 0           alcohol          5598
# 18             pets          4497
# 15            other          1795
# 5              bulk          1359

# %% [markdown]
# *** So we see that Produce is the department where maximum orders were made. ***

# %%
df = analysis_df.groupby('department')['reordered'].sum().reset_index()
df.columns = ['Department','Re-Ordered_Count']
df.sort_values(by='Re-Ordered_Count',ascending=False)
# Out:
#          Department  Re-Ordered_Count
# 19          produce            271886
# 7        dairy eggs            146502
# 3         beverages             75060
# 20           snacks             69102
# 10           frozen             56168
# 2            bakery             30692
# 16           pantry             29498
# 8              deli             27367
# 6      canned goods             22782
# 9   dry goods pasta             18885
# 13     meat seafood             17907
# 4         breakfast             16864
# 11        household             15372
# 1            babies              8084
# 17    personal care              7271
# 12    international              4522
# 0           alcohol              3397
# 14          missing              3148
# 18             pets              2834
# 5              bulk               786
# 15            other               697

# %% [markdown]
# *** Again Produce department is the place where maximum re-orders were made. It make sence because that is the department where most orders were made. No suprises there. ***

# %%
df = analysis_df.groupby('weekday')['reordered'].sum().reset_index()
df.sort_values(by='reordered',ascending=False)
# Out:
#      weekday  reordered
# 3     Sunday     197534
# 1     Monday     123376
# 2   Saturday     123173
# 0     Friday     107239
# 5    Tuesday      94469
# 4   Thursday      92454
# 6  Wednesday      90579

# %% [markdown]
# *** This is the reodering trend for the weekdays ***

# %%
df = analysis_df.groupby('range_of_hr')['reordered'].sum().reset_index()
df.sort_values(by='reordered',ascending=False)
# Out:
#   range_of_hr  reordered
# 0   Afternoon     336662
# 2     Morning     271813
# 1     Evening     182098
# 3       Night      38251

# %% [markdown]
# *** This is the reodering trend for the weekdays ***

# %%
df_alcohol = analysis_df[analysis_df['department']=='alcohol']
a = df_alcohol.groupby('weekday')['product_name'].count().reset_index()
a.columns = ['Weekday','Alcohol_Product_Count']
a.sort_values(by='Alcohol_Product_Count',ascending=False)
# Out:
#      Weekday  Alcohol_Product_Count
# 0     Friday                   1036
# 4   Thursday                    958
# 6  Wednesday                    834
# 2   Saturday                    765
# 3     Sunday                    713
# 5    Tuesday                    677
# 1     Monday                    615

# %% [markdown]
# *** So most alcohol products were bought on Friday. It make sence as Saturday & Sunday are generally holiday for most people ***

# %%
plt.figure(figsize = (12,8))
c = orders_df.groupby(['weekday','order_hour_of_day'])['order_id'].count().reset_index()
c = c.pivot('weekday','order_hour_of_day','order_id')
sns.heatmap(c)
plt.title('RelationShip between weekday and hour of day')
plt.show()

# %% [markdown]
# *** With this heat map we can clearly see that Monday morning and Sunady Afternoon are the most number of oders made ***

# %%
plt.figure(figsize = (16,8))
sns.countplot(x="days_since_prior_order", data=orders_df)
plt.ylabel('Count of orders')
plt.xlabel('Days since prior order')
plt.title("Frequency distribution by days since prior order")
plt.show()

# %% [markdown]
# *** We can see that after every 7 days or after every 30 days we re-oder the same products ***

# %%
plt.figure(figsize = (12,8))
plt.figure(figsize = (12,8))
sns.swarmplot(x='range_of_hr',y='days_since_prior_order',data=orders_df.head(1000))
#plt.ylabel('Number of orders in Thousands')
plt.show()

# %% [markdown]
# *** Again we see from the swarm plot above for any time of the day, reoder is maximum after 30 days. There is an intresting trend we can see in the re-odering after 7 days. It is reducing from Morning to Night ***

# %%
order_products_train_df = pd.read_csv('C:\\Users\\rchauhan\\Desktop\\Springboard Materials\\Capstone Project Data\\order_products__train.csv')
order_products_train_df.head(5)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
grouped_df = order_products_train_df.groupby("order_id")["add_to_cart_order"].aggregate("max").reset_index()
cnt_srs = grouped_df.add_to_cart_order.value_counts()
plt.figure(figsize = (12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Number of products in the given order', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# *** Here we see that 5 products are bought maximum times in each order ***

# %%
d = analysis_df['product_name'].value_counts().reset_index().head(20)
d
# Out:
#                      index  product_name
# 0                   Banana         18726
# 1   Bag of Organic Bananas         15480
# 2     Organic Strawberries         10894
# 3     Organic Baby Spinach          9784
# 4              Large Lemon          8135
# 5          Organic Avocado          7409
# 6     Organic Hass Avocado          7293
# 7             Strawberries          6494
# 8                    Limes          6033
# 9      Organic Raspberries          5546
# 10     Organic Blueberries          4966
# 11      Organic Whole Milk          4908
# 12        Organic Cucumber          4613
# 13        Organic Zucchini          4589
# 14    Organic Yellow Onion          4290
# 15          Organic Garlic          4158
# 16     Seedless Red Grapes          4059
# 17               Asparagus          3868
# 18  Organic Grape Tomatoes          3823
# 19       Organic Red Onion          3818

# %% [markdown]
# *** Here we see the top 20 products that are ordered are organic products & fruits. ***

# %%
a = analysis_df['aisle'].value_counts().head(20)
plt.figure(figsize=(12,8))
sns.barplot(a.index,a.values)
plt.xlabel('Aisle')
plt.ylabel('No of Occurance')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# *** Here we see Vegitables & Fruits are most important aisle ***

# %%
plt.figure(figsize = (12,8))
banana_df = analysis_df[(analysis_df['product_name']=='Banana') & (analysis_df['range_of_hr']== 'Morning')]
sns.countplot(x='weekday',data=banana_df)
plt.show()

# %%
plt.figure(figsize=(12,9))
temp_series = analysis_df['department'].value_counts()
labels = np.array(temp_series.index)
size = np.array((temp_series/temp_series.sum())*100)
plt.pie(size,labels=labels, 
        autopct='%1.1f%%')
plt.show()

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(12,9))
department_reordered = analysis_df.groupby('department')['reordered'].aggregate('mean').reset_index()
sns.pointplot(department_reordered['department'].values,department_reordered['reordered'].values)
plt.ylabel('Reorder ratio', fontsize=12)
plt.xlabel('Department', fontsize=12)
plt.title("Department wise reorder ratio", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# *** We see from the above chart that even though we order maximum from Produce department, we re-order maximum from Dairy Eggs department ***

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(14,9))
check = analysis_df[analysis_df['add_to_cart_order'] < 70]
df = check.groupby('add_to_cart_order')['reordered'].aggregate('mean').reset_index()
sns.pointplot(df['add_to_cart_order'].values,df['reordered'].values)
plt.ylabel('Reorder ratio', fontsize=12)
plt.xlabel('add_to_cart_order', fontsize=12)
plt.title("add_to_cart_order wise reorder ratio", fontsize=15)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# *** The trend looks like the first to add to cart product is more likely to be re-ordered ***

# %% [markdown]
# Since our objective is to figure out the re-orders, let us check out the re-order percentage in prior set and train set.

# %%
order_product_prior_df['reordered'].sum()/order_product_prior_df.shape[0]
# Out:
# 0.5896974667922161

# %% [markdown]
# *** Almost 60% of the products are reorderd in the Prior dataset. Now lets find in training dataset what is the percentage of reordered products ***

# %%
order_product_train_df['reordered'].sum()/order_product_train_df.shape[0]
# Out:
# 0.5985944127509629

# %% [markdown]
# *** So we see both Training & Prior dataset has close to 60% of reordered products. ***

# %% [markdown]
# *** Now that we have seen 60% of the products are re-ordered, there will also be situations when none of the products are re-ordered. Let us check that now. ***

# %%
grouped_df = order_product_prior_df.groupby("order_id")["reordered"].aggregate("sum").reset_index()
grouped_df["reordered"].loc[grouped_df["reordered"]>1] = 1
grouped_df.reordered.value_counts() / grouped_df.shape[0]
# Out:
# 1    0.879151
# 0    0.120849
# Name: reordered, dtype: float64

# %%
grouped_df = order_product_train_df.groupby("order_id")["reordered"].aggregate("sum").reset_index()
grouped_df["reordered"].loc[grouped_df["reordered"]>1] = 1
grouped_df.reordered.value_counts() / grouped_df.shape[0]
# Out:
# 1    0.93444
# 0    0.06556
# Name: reordered, dtype: float64

# %% [markdown]
# *** About 12% of the orders in prior set has no re-ordered items while in the train set it is 6.5%.***

# %%
grouped =order_product_department_aisle.groupby(['department', 'aisle'])['product_id'].aggregate('count').reset_index()
grouped.columns = ['Department','Aisle','CountOfProduct']
grouped.sort_values(by='CountOfProduct', ascending=False, inplace=True)
grouped.head()
# Out:
#      Department                       Aisle  CountOfProduct
# 120     produce            fresh vegetables          150609
# 118     produce                fresh fruits          150473
# 122     produce  packaged vegetables fruits           78493
# 42   dairy eggs                      yogurt           55240
# 38   dairy eggs             packaged cheese           41699

# %%
fig, axes = plt.subplots(7,3, figsize=(20,45), gridspec_kw =  dict(hspace=1.4))
for (Aisle, group), ax in zip(grouped.groupby(['Department']), axes.flatten()):
    g = sns.barplot(group.Aisle, group.CountOfProduct , ax=ax)
    ax.set(xlabel = "Aisles", ylabel=" Number of products")
    g.set_xticklabels(labels = group.Aisle,rotation=90, fontsize=12)
    ax.set_title(aisle, fontsize=15)
plt.show()

# %% [markdown]
# *** Above list of bar charts shows Aisle grouped by different department and products sold from that aisle ***

# %%
merged_reorders = pd.merge(order_products_prior_df, orders_df, on='order_id', how='left')

# %%
count_reordered = merged_reorders['reordered'].value_counts()
count_reordered
# Out:
# 1    19126536
# 0    13307953
# Name: reordered, dtype: int64

# %%
grouped_reorders = merged_reorders.groupby(["order_hour_of_day"])["reordered"].aggregate("count").reset_index()
grouped_reorders
# Out:
#     order_hour_of_day  reordered
# 0                   0     218948
# 1                   1     115786
# 2                   2      69434
# 3                   3      51321
# 4                   4      53283
# 5                   5      88062
# 6                   6     290795
# 7                   7     891937
# 8                   8    1719973
# 9                   9    2456713
# 10                 10    2764426
# 11                 11    2738582
# 12                 12    2620847
# 13                 13    2663292
# 14                 14    2691548
# 15                 15    2664533
# 16                 16    2537458
# 17                 17    2089465
# 18                 18    1637923
# 19                 19    1259401
# 20                 20     977038
# 21                 21     796370
# 22                 22     634734
# 23                 23     402620

# %%
plt.figure(figsize=(12,12))
sns.barplot(grouped_reorders.order_hour_of_day, grouped_reorders.reordered)
plt.ylabel('Total number of reordered products', fontsize=14)
plt.xlabel('order_hour_of_day', fontsize=14)
plt.show()

# %% [markdown]
# *** Above graph shows re-ordered products over the hour of the day. So we see re-ordered mostly happen in morning between 10 & 11 ***
